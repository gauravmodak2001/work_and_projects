# %% [markdown]
# # Git And Github Tutorials By Kunal Kushwaha
#
# https://www.youtube.com/watch?v=apGV9Kg7ics&t=1368s

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>
#
# --> "ls" command gives the all files name available in mentioned path folder
#     This command is very useful to see available files in the folder.
#     While the "ls" command does not work on the Windows Command Prompt, it does work within    Windows PowerShell. Windows PowerShell is a very powerful utility, and even allows you to carry out complex file management tasks such as creating, removing, and copying files and folders straight through the terminal.
#
# --> For windows command prompt you can use "dir" command which shows all the available directories in the mentioned folder.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst>cd..</font>
#
# --> "c.." command used to go back to the previous directory in the file path. It simply act as a      button.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst>cd Git_And_Github</font>
#
# --> By using "cd name_of_folder" command you can go in any folder you want. It act as a double click on a folder using command line
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst>clear</font>
#
# --> 'Clear' command used to clear to clean the powershell. Basically, it will remove all the written code and make your powershell window clean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst>git init</font>
#
# -->

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>

# %% [markdown]
# ### <font color=green>**PS C:\Users\gaura\Desktop\Data Analyst> ls**</font>
