# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_2018=pd.concat(
    map(pd.read_csv, ['Bike Share Toronto Ridership_Q1 2018.csv','Bike Share Toronto Ridership_Q2 2018.csv','Bike Share Toronto Ridership_Q3 2018.csv','Bike Share Toronto Ridership_Q4 2018.csv']), ignore_index=True)

# %%
dataset_2018
# Out:
#          trip_id  trip_duration_seconds  from_station_id   trip_start_time  \
# 0        2383648                    393             7018     1/1/2018 0:47
# 1        2383649                    625             7184     1/1/2018 0:52
# 2        2383650                    233             7235     1/1/2018 0:55
# 3        2383651                   1138             7202     1/1/2018 0:57
# 4        2383652                    703             7004     1/1/2018 1:00
# ...          ...                    ...              ...               ...
# 1922950  4581273                    379             7088  12/31/2018 23:43
# 1922951  4581274                    306             7030  12/31/2018 23:45
# 1922952  4581275                    340             7020  12/31/2018 23:49
# 1922953  4581276                   1466             7014  12/31/2018 23:52
# 1922954  4581277                    333             7299  12/31/2018 23:58
#
# ...

# %%
dataset_2018.isnull().sum()
# Out:
# trip_id                  0
# trip_duration_seconds    0
# from_station_id          0
# trip_start_time          0
# from_station_name        0
# trip_stop_time           0
# to_station_id            0
# to_station_name          0
# user_type                0
# dtype: int64

# %%
df_duplicates_removed = dataset_2018.drop_duplicates(subset=['trip_id'])
dataset_2018
# Out:
#          trip_id  trip_duration_seconds  from_station_id   trip_start_time  \
# 0        2383648                    393             7018     1/1/2018 0:47
# 1        2383649                    625             7184     1/1/2018 0:52
# 2        2383650                    233             7235     1/1/2018 0:55
# 3        2383651                   1138             7202     1/1/2018 0:57
# 4        2383652                    703             7004     1/1/2018 1:00
# ...          ...                    ...              ...               ...
# 1922950  4581273                    379             7088  12/31/2018 23:43
# 1922951  4581274                    306             7030  12/31/2018 23:45
# 1922952  4581275                    340             7020  12/31/2018 23:49
# 1922953  4581276                   1466             7014  12/31/2018 23:52
# 1922954  4581277                    333             7299  12/31/2018 23:58
#
# ...

# %%
dataset_2018=dataset_2018.dropna(how='all')

# %%
dataset_2018 = dataset_2018.dropna()
dataset_2018
# Out:
#          trip_id  trip_duration_seconds  from_station_id   trip_start_time  \
# 0        2383648                    393             7018     1/1/2018 0:47
# 1        2383649                    625             7184     1/1/2018 0:52
# 2        2383650                    233             7235     1/1/2018 0:55
# 3        2383651                   1138             7202     1/1/2018 0:57
# 4        2383652                    703             7004     1/1/2018 1:00
# ...          ...                    ...              ...               ...
# 1922950  4581273                    379             7088  12/31/2018 23:43
# 1922951  4581274                    306             7030  12/31/2018 23:45
# 1922952  4581275                    340             7020  12/31/2018 23:49
# 1922953  4581276                   1466             7014  12/31/2018 23:52
# 1922954  4581277                    333             7299  12/31/2018 23:58
#
# ...

# %%
dataset_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1922955 entries, 0 to 1922954
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trip_id                int64
#  1   trip_duration_seconds  int64
#  2   from_station_id        int64
#  3   trip_start_time        object
#  4   from_station_name      object
#  5   trip_stop_time         object
#  6   to_station_id          int64
#  7   to_station_name        object
#  8   user_type              object
# dtypes: int64(4), object(5)
# memory usage: 146.7+ MB

# %%
# overwriting data after changing format
dataset_2018["trip_start_time"]= pd.to_datetime(dataset_2018["trip_start_time"])
  
# info of data
dataset_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1922955 entries, 0 to 1922954
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trip_id                int64
#  1   trip_duration_seconds  int64
#  2   from_station_id        int64
#  3   trip_start_time        datetime64[ns]
#  4   from_station_name      object
#  5   trip_stop_time         object
#  6   to_station_id          int64
#  7   to_station_name        object
#  8   user_type              object
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 146.7+ MB

# %%
dataset_2018.user_type.unique()
# Out:
# array(['Annual Member', 'Casual Member'], dtype=object)

# %%
dt_series = pd.Series(['28 July 2020', '2013-01-16',
                       '20160229 18:14', '5/03/2019 2215',
                       '20151204 09:23'])
  
# display the series initially
print("Series of date strings:")
print(dt_series)
  
# display the series after 
# being converted to a time series
print("\nSeries of date strings after " + 
      "being converted to a timeseries:")
  
print(pd.to_datetime(dt_series))
# Out:
# Series of date strings:
# 0      28 July 2020
# 1        2013-01-16
# 2    20160229 18:14
# 3    5/03/2019 2215
# 4    20151204 09:23
# dtype: object
#
# Series of date strings after being converted to a timeseries:
# 0   2020-07-28 00:00:00
# 1   2013-01-16 00:00:00
# 2   2016-02-29 18:14:00
# 3   2019-05-03 22:15:00
# 4   2015-12-04 09:23:00
# dtype: datetime64[ns]

# %%
dataset_2018.to_station_name.unique()
# Out:
# array(['Bathurst St / Fort York Blvd', 'Central Tech  (Harbord St)',
#        'Bay St / Albert St', 'Phoebe St / Spadina Ave',
#        'Princess St / Adelaide St E', 'Pears Av / Avenue Rd',
#        'Union Station', 'Queen St W / James St', 'Gould St / Mutual St',
#        'Queen St W / Gladstone Ave', 'St. George St / Bloor St W',
#        'Claremont St / Dundas St W', 'Fort York Blvd / Garrison Rd',
#        'Ulster St / Bathurst St', 'Castle Frank Station',
#        'Queen St W / Close Ave', 'Madison Ave / Bloor St W',
#        'Bloor St W / Christie St', 'Lower Spadina Ave / Lakeshore Blvd',
#        'King St W / Bay St (East Side)', 'King St W / Joe Shuster Way',
#        'Lower Sherbourne St / The Esplanade', 'College St / Crawford St',
#        'Church St / Alexander St', 'Widmer St / Adelaide St W',
#        'Fort York  Blvd / Capreol Ct',
#        'Dovercourt Rd / Harrison St (Green P) - SMART',
#        'East Liberty St / Pirandello St', 'Danforth Ave / Gough Ave',
# ...

# %%
dataset_2018.shape
# Out:
# (1922955, 9)

# %%
new=dataset_2018["trip_stop_time"].str.split(" ", n = 1, expand = True)
new
# Out:
#                   0      1
# 0          1/1/2018   0:54
# 1          1/1/2018   1:03
# 2          1/1/2018   0:59
# 3          1/1/2018   1:16
# 4          1/1/2018   1:12
# ...             ...    ...
# 1922950  12/31/2018  23:49
# 1922951  12/31/2018  23:50
# 1922952  12/31/2018  23:55
# 1922953    1/1/2019   0:17
# 1922954    1/1/2019   0:04
#
# [1922955 rows x 2 columns]

# %%
# making separate first name column from new data frame
dataset_2018["date"]= new[0]
  
# making separate last name column from new data frame
dataset_2018["start_time"]= new[1]

dataset_2018.head()
# Out:
#    trip_id  trip_duration_seconds  from_station_id     trip_start_time  \
# 0  2383648                    393             7018 2018-01-01 00:47:00
# 1  2383649                    625             7184 2018-01-01 00:52:00
# 2  2383650                    233             7235 2018-01-01 00:55:00
# 3  2383651                   1138             7202 2018-01-01 00:57:00
# 4  2383652                    703             7004 2018-01-01 01:00:00
#
#                          from_station_name trip_stop_time  to_station_id  \
# 0                   Bremner Blvd / Rees St  1/1/2018 0:54           7176
# 1               Ossington Ave / College St  1/1/2018 1:03           7191
# 2  Bay St / College St (West Side) - SMART  1/1/2018 0:59           7021
# 3         Queen St W / York St (City Hall)  1/1/2018 1:16           7020
# 4                  University Ave / Elm St  1/1/2018 1:12           7060
#
#                 to_station_name      user_type      date start_time
# ...

# %%
# overwriting data after changing format
dataset_2018["start_time"]= pd.to_datetime(dataset_2018["start_time"])
  
# info of data
dataset_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1922955 entries, 0 to 1922954
# Data columns (total 11 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trip_id                int64
#  1   trip_duration_seconds  int64
#  2   from_station_id        int64
#  3   trip_start_time        datetime64[ns]
#  4   from_station_name      object
#  5   trip_stop_time         object
#  6   to_station_id          int64
#  7   to_station_name        object
#  8   user_type              object
#  9   date                   object
#  10  start_time             datetime64[ns]
# dtypes: datetime64[ns](2), int64(4), object(5)
# memory usage: 176.1+ MB

# %% [markdown]
# ## Questions to answer
#
# 1) compare annual and casual by their sums and plot them on bar chart
#
# 2) From which station most of traffic travels to ?
#
# 3) Most common destination stations
#
# 4) Average time travelling with bike
#
# 5) At what time most of peoples consider to take bike ride ?

# %% [markdown]
# ## 1) compare annual and casual user_type by their sums and plot them on bar chart

# %%
dataset_2018.user_type.unique()
# Out:
# array(['Annual Member', 'Casual Member'], dtype=object)

# %%
item_counts = dataset_2018["user_type"].value_counts(normalize=True)
print(item_counts)
# Out:
# Annual Member    0.818001
# Casual Member    0.181999
# Name: user_type, dtype: float64

# %%
item_counts.plot.pie()
# Out:
# <AxesSubplot:ylabel='user_type'>

# %%
ax = item_counts.plot.bar(stacked=True)

# %% [markdown]
# ## 2) From which station most of traffic travels to ?

# %%
# Finding By station ID
croweded_stn= dataset_2018['from_station_id'].value_counts()
croweded_stn
# Out:
# 7076    24017
# 7016    22743
# 7033    19869
# 7030    19184
# 7042    19131
#         ...
# 7359      259
# 7301      201
# 7380      190
# 7387      125
# 7219        1
# Name: from_station_id, Length: 359, dtype: int64

# %%
top_ten_crowded_stn=croweded_stn.head(10)

# %%
top_ten_crowded_stn.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
# Finding By station Name 
croweded_stn_name= dataset_2018['from_station_name'].value_counts()
croweded_stn_name
# Out:
# York St / Queens Quay W                    24017
# Bay St / Queens Quay W (Ferry Terminal)    22743
# Union Station                              19869
# Bay St / Wellesley St W                    19184
# Sherbourne St / Wellesley St E             19131
#                                            ...
# Rosedale Park (20 Schofield Ave)             259
# Primrose Ave / Davenport Rd                  201
# Erskine Ave / Yonge St SMART                 190
# Mortimer Ave / Carlaw Ave SMART              125
# Wolfpack - 7219                                1
# Name: from_station_name, Length: 359, dtype: int64

# %%
top_ten_crowded_stn_names=croweded_stn_name.head(10)

# %%
top_ten_crowded_stn_names.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3) Most common destination stations

# %%
# Finding By station Name 
croweded_destination_name= dataset_2018['to_station_name'].value_counts()
croweded_destination_name
# Out:
# York St / Queens Quay W                    25754
# Union Station                              25673
# Bay St / Queens Quay W (Ferry Terminal)    24248
# Princess St / Adelaide St E                19986
# Dundas St W / Yonge St                     18540
#                                            ...
# Hocken Ave./Vaughan Rd.                      182
# Erskine Ave / Yonge St SMART                 154
# Primrose Ave / Davenport Rd                  144
# Mortimer Ave / Carlaw Ave SMART              109
# Wolfpack - 7219                                4
# Name: to_station_name, Length: 359, dtype: int64

# %%
top_ten_crowded_destination_names=croweded_destination_name.head(10)

# %%
top_ten_crowded_destination_names.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4) Average time travelling with bike

# %%
dataset_2018['trip_duration_seconds']
# Out:
# 0           393
# 1           625
# 2           233
# 3          1138
# 4           703
#            ...
# 1922950     379
# 1922951     306
# 1922952     340
# 1922953    1466
# 1922954     333
# Name: trip_duration_seconds, Length: 1922955, dtype: int64

# %% [markdown]
# ## 5) At what time most of peoples consider to take bike ride ?

# %%
dataset_2018.head()
# Out:
#    trip_id  trip_duration_seconds  from_station_id     trip_start_time  \
# 0  2383648                    393             7018 2018-01-01 00:47:00
# 1  2383649                    625             7184 2018-01-01 00:52:00
# 2  2383650                    233             7235 2018-01-01 00:55:00
# 3  2383651                   1138             7202 2018-01-01 00:57:00
# 4  2383652                    703             7004 2018-01-01 01:00:00
#
#                          from_station_name trip_stop_time  to_station_id  \
# 0                   Bremner Blvd / Rees St  1/1/2018 0:54           7176
# 1               Ossington Ave / College St  1/1/2018 1:03           7191
# 2  Bay St / College St (West Side) - SMART  1/1/2018 0:59           7021
# 3         Queen St W / York St (City Hall)  1/1/2018 1:16           7020
# 4                  University Ave / Elm St  1/1/2018 1:12           7060
#
#                 to_station_name      user_type      date start_time
# ...

# %%
x = dataset_2018['start_time'].value_counts()
x
# Out:
# 2022-01-17 17:25:00    4175
# 2022-01-17 17:29:00    4091
# 2022-01-17 08:59:00    4039
# 2022-01-17 17:31:00    4029
# 2022-01-17 17:19:00    4013
#                        ...
# 2022-01-17 04:38:00      35
# 2022-01-17 04:36:00      35
# 2022-01-17 04:31:00      34
# 2022-01-17 04:39:00      32
# 2022-01-17 03:54:00      30
# Name: start_time, Length: 1440, dtype: int64

# %%
x.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
